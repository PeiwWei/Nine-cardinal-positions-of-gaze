# %%
import os
from PIL import Image

def resize_image(image_path, output_path, size=(800, 300)):
    """
    调整图像大小并保存到指定路径。

    :param image_path: 原始图像路径
    :param output_path: 调整后图像保存路径
    :param size: 目标尺寸 (宽度, 高度)
    """
    with Image.open(image_path) as img:
        img_resized = img.resize(size, Image.LANCZOS)
        img_resized.save(output_path)

def main():
    # 设置主文件夹路径
    main_folder = "./cropped_img/"  # 替换为您的主文件夹路径
    
    # 遍历主文件夹下的所有子文件夹
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)
        
        # 检查是否是文件夹
        if not os.path.isdir(subfolder_path):
            continue
        
        # 获取子文件夹内的所有图片文件
        image_files = [f for f in os.listdir(subfolder_path) if f.endswith(".JPG") or f.endswith(".jpg") ]
        image_files.sort(key=lambda x: int(x[1:-4]))  # 按数字顺序排序
        
        
        # 检查是否正好有9张图片
        if len(image_files) != 9:
            print(f"警告：子文件夹 {subfolder} 中的图片数量不是9张")
            continue
        
        resized_images = []
        
        # 调整每张图片的大小
        for img_file in image_files:
            original_path = os.path.join(subfolder_path, img_file)
            resized_path = os.path.join(subfolder_path, f"resized_{img_file}")
            resize_image(original_path, resized_path, size=(800, 300))
            resized_images.append(resized_path)
        
        # 创建空白画布（3x3布局）
        total_width = 3 * 800  # 3张图片宽度相加
        total_height = 3 * 300  # 3张图片高度相加
        composite = Image.new("RGB", (total_width, total_height))
        
        # 定义各位置偏移量
        positions = [
            (0, 0),    # 01左上
            (800, 0),  # 02中上
            (1600, 0), # 03右上
            (0, 300),  # 04中左
            (800, 300),# 05中心
            (1600, 300),# 06中右
            (0, 600),  # 07左下
            (800, 600),# 08中下
            (1600, 600)# 09右下
        ]
        
        # 合并图片
        for i in range(9):
            img_path = resized_images[i]
            img = Image.open(img_path)
            x_offset, y_offset = positions[i]
            composite.paste(img, (x_offset, y_offset))
        
        # 保存合成图
        output_filename = f"{subfolder}.jpg"
        output_path = os.path.join(main_folder, output_filename)
        composite.save(output_path)
        print(f"已合成并保存：{output_path}")
        
        # 可选：删除临时调整大小的图片以节省空间
        for img_file in resized_images:
            os.remove(img_file)

if __name__ == "__main__":
    main()
# Out:
# 已合成并保存：./cropped_img/20170105gaochengyi.jpg
# 已合成并保存：./cropped_img/20170105lihaoning.jpg
# 已合成并保存：./cropped_img/20170105xiaziyuan.jpg
# 已合成并保存：./cropped_img/20170112xuzhenliang.jpg
# 已合成并保存：./cropped_img/20170116yindingkang.jpg
# 已合成并保存：./cropped_img/20170119niming.jpg
# 已合成并保存：./cropped_img/20170208daishijie.jpg
# 已合成并保存：./cropped_img/20170220hujiayan.jpg
# 已合成并保存：./cropped_img/20170220sunshiyu.jpg
# 已合成并保存：./cropped_img/20170220wangziqian.jpg
# 已合成并保存：./cropped_img/20170223gukeyin.jpg
# 已合成并保存：./cropped_img/20170227futianjian.jpg
# 已合成并保存：./cropped_img/20170309zhuyuanyuan.jpg
# 已合成并保存：./cropped_img/20170316wujijie.jpg
# 已合成并保存：./cropped_img/20170320luqingyi.jpg
# 已合成并保存：./cropped_img/20170323cenxinze.jpg
# 已合成并保存：./cropped_img/20170323yaomingzhe.jpg
# 已合成并保存：./cropped_img/20170323zhangjingrui.jpg
# 已合成并保存：./cropped_img/20170406yanzhaohui.jpg
# 已合成并保存：./cropped_img/20170411zhangyazhi.jpg
# 已合成并保存：./cropped_img/20170413dutianchen.jpg
# 已合成并保存：./cropped_img/20170504lianwenyue.jpg
# 已合成并保存：./cropped_img/20170504zhuchenxuan.jpg
# 已合成并保存：./cropped_img/20170511wangshuoying.jpg
# 已合成并保存：./cropped_img/20170515sutianci.jpg
# 已合成并保存：./cropped_img/20170605wuyuhe.jpg
# 已合成并保存：./cropped_img/20170612huangjunxi.jpg
# 已合成并保存：./cropped_img/20170615qianyixuan.jpg
# 已合成并保存：./cropped_img/20170615xiexintian.jpg
# 已合成并保存：./cropped_img/20170619wangyichen.jpg
# 已合成并保存：./cropped_img/20170626dingyuning.jpg
# 已合成并保存：./cropped_img/20170706chenrunhe.jpg
# 已合成并保存：./cropped_img/20170713chengyunxi.jpg
# 已合成并保存：./cropped_img/20170717wangjunjie.jpg
# 已合成并保存：./cropped_img/20170807linjinghao.jpg
# 已合成并保存：./cropped_img/20170814fengjiayi.jpg
# 已合成并保存：./cropped_img/20170817yeweilian.jpg
# 已合成并保存：./cropped_img/20170821yanhan.jpg
# 已合成并保存：./cropped_img/20170828lilan.jpg
# 已合成并保存：./cropped_img/20170828zhangmenghao.jpg
# 已合成并保存：./cropped_img/20170907dushihan.jpg
# 已合成并保存：./cropped_img/20170911cenlinze.jpg
# 已合成并保存：./cropped_img/20170928zhengyuxuan.jpg
# 已合成并保存：./cropped_img/20170928zhousiqi.jpg
# 已合成并保存：./cropped_img/20171009zhengnuoze.jpg
# 已合成并保存：./cropped_img/20171102liuziyun.jpg
# 已合成并保存：./cropped_img/20171102zhangyiran.jpg
# 已合成并保存：./cropped_img/20171130cengshuqi.jpg
# 已合成并保存：./cropped_img/20171130chenyuezhou.jpg
# 已合成并保存：./cropped_img/20171130yuansibai.jpg
# 已合成并保存：./cropped_img/20171207wujiaqi.jpg
# 已合成并保存：./cropped_img/20171214wangyiran.jpg
# 已合成并保存：./cropped_img/20171218tiansijun.jpg
# 已合成并保存：./cropped_img/20171221yaodexin.jpg
# 已合成并保存：./cropped_img/20180111caiyihan.jpg
# 已合成并保存：./cropped_img/20180122zhangxingjialin.jpg
# 已合成并保存：./cropped_img/20180125huangyichen.jpg
# 已合成并保存：./cropped_img/20180201sunyan.jpg
# 已合成并保存：./cropped_img/20180201zouzhongliang.jpg
# 已合成并保存：./cropped_img/20180226ouyangwenhao.jpg
# 已合成并保存：./cropped_img/20180305luanyixuan.jpg
# 已合成并保存：./cropped_img/20180312zoujinchen.jpg
# 已合成并保存：./cropped_img/20180322zhangziheng.jpg
# 已合成并保存：./cropped_img/20180326chenyi.jpg
# 已合成并保存：./cropped_img/20180326jiangyicheng.jpg
# 已合成并保存：./cropped_img/20180326luxiangyi.jpg
# 已合成并保存：./cropped_img/20180329chendaiyun.jpg
# 已合成并保存：./cropped_img/20180329lizixuan.jpg
# 已合成并保存：./cropped_img/20180409chenjunhao.jpg
# 已合成并保存：./cropped_img/20180409penganqi.jpg
# 已合成并保存：./cropped_img/20180409zhengjiayue.jpg
# 已合成并保存：./cropped_img/20180412dongruochen.jpg
# 已合成并保存：./cropped_img/20180412wangpengyu.jpg
# 已合成并保存：./cropped_img/20180419guyanning.jpg
# 已合成并保存：./cropped_img/20180419wanganjing.jpg
# 已合成并保存：./cropped_img/20180517huanghonglan.jpg
# 已合成并保存：./cropped_img/20180524zhangruyu.jpg
# 已合成并保存：./cropped_img/20180531jinyimeng.jpg
# 已合成并保存：./cropped_img/20180531wukaixuan.jpg
# 已合成并保存：./cropped_img/20180625fengyuhan.jpg
# 已合成并保存：./cropped_img/20180702wangwenjin.jpg
# 已合成并保存：./cropped_img/20180705linjiajia.jpg
# 已合成并保存：./cropped_img/20180705peixinlei.jpg
# 已合成并保存：./cropped_img/20180705wangyuexin.jpg
# 已合成并保存：./cropped_img/20180709zhaozhen.jpg
# 已合成并保存：./cropped_img/20180712linpeiyu.jpg
# 已合成并保存：./cropped_img/20180719qiaoyang.jpg
# 已合成并保存：./cropped_img/20180726chenjiayi.jpg
# 已合成并保存：./cropped_img/20180726lihongji.jpg
# 已合成并保存：./cropped_img/20180802chensitong.jpg
# 已合成并保存：./cropped_img/20180802xuyun.jpg
# 已合成并保存：./cropped_img/20180809zhangfurong.jpg
# 已合成并保存：./cropped_img/20180813wanglinfei.jpg
# 已合成并保存：./cropped_img/20180823liuqingyu.jpg
# 已合成并保存：./cropped_img/20180823luotianyi.jpg
# 已合成并保存：./cropped_img/20180823tongwenjing.jpg
# 已合成并保存：./cropped_img/20180903yangyi.jpg
# 已合成并保存：./cropped_img/20180910panzixin.jpg
# 已合成并保存：./cropped_img/20180927maoweixin.jpg
# 已合成并保存：./cropped_img/20181008xuzhihao.jpg
# 已合成并保存：./cropped_img/20181011yeyingluo.jpg
# 已合成并保存：./cropped_img/20181018songqianyuxuan.jpg
# 已合成并保存：./cropped_img/20181022zhangleqi.jpg
# 已合成并保存：./cropped_img/20181022zhangyujie.jpg
# 已合成并保存：./cropped_img/20181105huangyihan.jpg
# 已合成并保存：./cropped_img/20181115zhangzhelin.jpg
# 已合成并保存：./cropped_img/20181129qianbeihai.jpg
# 已合成并保存：./cropped_img/20181206linzibo.jpg
# 已合成并保存：./cropped_img/20181210chenyuxin.jpg
# 已合成并保存：./cropped_img/20181213lihaochen.jpg
# 已合成并保存：./cropped_img/20181213zhujinhan.jpg
# 已合成并保存：./cropped_img/20181217xiechenhang.jpg
# 已合成并保存：./cropped_img/20181220chenluoying.jpg
# 已合成并保存：./cropped_img/20181220jianghaowen.jpg
# 已合成并保存：./cropped_img/20181227jiangruoxi.jpg
# 已合成并保存：./cropped_img/20181227jiangwei.jpg
# 已合成并保存：./cropped_img/20190103hanyi.jpg
# 已合成并保存：./cropped_img/20190107caozhengyang.jpg
# 已合成并保存：./cropped_img/20190107dingjiajun.jpg
# 已合成并保存：./cropped_img/20190107lijiajun.jpg
# 已合成并保存：./cropped_img/20190110caiziyan.jpg
# 已合成并保存：./cropped_img/20190114lifeiran.jpg
# 已合成并保存：./cropped_img/20190124zhangsiyuan.jpg
# 已合成并保存：./cropped_img/20190128daiziyue.jpg
# 已合成并保存：./cropped_img/20190128fengzijun.jpg
# 已合成并保存：./cropped_img/20190128songyanghui.jpg
# 已合成并保存：./cropped_img/20190131songxinchen.jpg
# 已合成并保存：./cropped_img/20190221zhangjunyu.jpg
# 已合成并保存：./cropped_img/20190304caoleqi.jpg
# 已合成并保存：./cropped_img/20190311jieyunqing.jpg
# 已合成并保存：./cropped_img/20190321taojiayi.jpg
# 已合成并保存：./cropped_img/20190325chenqinxin.jpg
# 已合成并保存：./cropped_img/20190325wujiale.jpg
# 已合成并保存：./cropped_img/20190404biyihan.jpg
# 已合成并保存：./cropped_img/20190408zhuxue.jpg
# 已合成并保存：./cropped_img/20190418lumingqian.jpg
# 已合成并保存：./cropped_img/20190422chenshuanglian.jpg
# 已合成并保存：./cropped_img/20190603xiexiaofang.jpg
# 已合成并保存：./cropped_img/20190603zhangyichen.jpg
# 已合成并保存：./cropped_img/20190606liuruoling.jpg
# 已合成并保存：./cropped_img/20190701gengxinlei.jpg
# 已合成并保存：./cropped_img/20190711jiangzixuan.jpg
# 已合成并保存：./cropped_img/20190711songyiheng.jpg
# 已合成并保存：./cropped_img/20190715xuehetong.jpg
# 已合成并保存：./cropped_img/20190722wangmenghan.jpg
# 已合成并保存：./cropped_img/20190722zhangyiyan.jpg
# 已合成并保存：./cropped_img/20190729chenyaopu.jpg
# 已合成并保存：./cropped_img/20190729lichengtao.jpg
# 已合成并保存：./cropped_img/20190808gaoshang.jpg
# 已合成并保存：./cropped_img/20190808huamingyue.jpg
# 已合成并保存：./cropped_img/20190808shixinrui.jpg
# 已合成并保存：./cropped_img/20190815danxicheng.jpg
# 已合成并保存：./cropped_img/20190822shenxinyue.jpg
# 已合成并保存：./cropped_img/20190826luzhekai.jpg
# 已合成并保存：./cropped_img/20190905zhangxinyan.jpg
# 已合成并保存：./cropped_img/20190916huwanmeng.jpg
# 已合成并保存：./cropped_img/20190916linyutang.jpg
# 已合成并保存：./cropped_img/20190916sunruichen.jpg
# 已合成并保存：./cropped_img/20190919wangyi.jpg
# 已合成并保存：./cropped_img/20190919zhouxinyuan.jpg
# 已合成并保存：./cropped_img/20191017fanqinchen.jpg
# 已合成并保存：./cropped_img/20191021yuboyu.jpg
# 已合成并保存：./cropped_img/20191021zhangqinyan.jpg
# 已合成并保存：./cropped_img/20191031peiyouli.jpg
# 已合成并保存：./cropped_img/20191111chenjingyue.jpg
# 已合成并保存：./cropped_img/20191118liyutong.jpg
# 已合成并保存：./cropped_img/20191121chenxiaodong.jpg
# 已合成并保存：./cropped_img/20191124lizhe.jpg
# 已合成并保存：./cropped_img/20191124shenjiaying.jpg
# 已合成并保存：./cropped_img/20191128peiyouli.jpg
# 已合成并保存：./cropped_img/20191202huangzimo.jpg
# 已合成并保存：./cropped_img/20191209wuhaolin.jpg
# 已合成并保存：./cropped_img/20191212lichengtao.jpg
# 已合成并保存：./cropped_img/20191216jiziyu.jpg
# 已合成并保存：./cropped_img/20191219minrui.jpg
# 已合成并保存：./cropped_img/20191219zhangsiyan.jpg
# 已合成并保存：./cropped_img/20191223changhao.jpg
# 已合成并保存：./cropped_img/20191226chenhao.jpg
# 已合成并保存：./cropped_img/20191226chuna.jpg
# 已合成并保存：./cropped_img/20191230maqiannuo.jpg
# 已合成并保存：./cropped_img/20200106songyuhui.jpg
# 已合成并保存：./cropped_img/20200109chenxiangjian.jpg
# 已合成并保存：./cropped_img/20200109liuniannian.jpg
# 已合成并保存：./cropped_img/20200109maxinyu.jpg
# 已合成并保存：./cropped_img/20200109weiyiyi.jpg
# 已合成并保存：./cropped_img/20200109yanwensheng.jpg
# 已合成并保存：./cropped_img/20200113peiyucheng.jpg
# 已合成并保存：./cropped_img/20200120heyuming.jpg
# 已合成并保存：./cropped_img/20200323huangjiawei.jpg
# 已合成并保存：./cropped_img/20200330hanyujing.jpg
# 已合成并保存：./cropped_img/20200330jinyihan.jpg
# 已合成并保存：./cropped_img/20200409guoyan.jpg
# 已合成并保存：./cropped_img/20200409liuyihan.jpg
# 已合成并保存：./cropped_img/20200413yanghuiya.jpg
# 已合成并保存：./cropped_img/20200423cuixiaoyi.jpg
# 已合成并保存：./cropped_img/20200423tanzelin.jpg
# 已合成并保存：./cropped_img/20200427sunyi.jpg
# 已合成并保存：./cropped_img/20200427zhuyiyan.jpg
# 已合成并保存：./cropped_img/20200521qianbinchen.jpg
# 已合成并保存：./cropped_img/20200528huangyihan.jpg
# 已合成并保存：./cropped_img/20201015chenjia.jpg
# 已合成并保存：./cropped_img/20201015liuzixuan.jpg
# 已合成并保存：./cropped_img/20201019dongyinuo.jpg
# 已合成并保存：./cropped_img/20201022guoshiheng.jpg
# 已合成并保存：./cropped_img/20201022songzhengxuan.jpg
# 已合成并保存：./cropped_img/20201026xuchenyi.jpg
# 已合成并保存：./cropped_img/20201026yuzihao.jpg
# 已合成并保存：./cropped_img/20201102shikaijie.jpg
# 已合成并保存：./cropped_img/20201102yangjinrun.jpg
# 已合成并保存：./cropped_img/20201102zhangsongjie.jpg
# 已合成并保存：./cropped_img/20201112lvcan.jpg
# 已合成并保存：./cropped_img/20201221linyuxi.jpg
# 已合成并保存：./cropped_img/20201221zhouningmeng.jpg
# 已合成并保存：./cropped_img/20201228yujialing.jpg
# 已合成并保存：./cropped_img/20201231linyuxi.jpg
# 已合成并保存：./cropped_img/20210111geyumeng.jpg
# 已合成并保存：./cropped_img/20210114wangyiqin.jpg
# 已合成并保存：./cropped_img/20210114wangyutian.jpg
# 已合成并保存：./cropped_img/20210118guxinyu.jpg
# 已合成并保存：./cropped_img/20210201majingxuan.jpg
# 已合成并保存：./cropped_img/20210218yangyi.jpg
# 已合成并保存：./cropped_img/20210222linfan.jpg
# 已合成并保存：./cropped_img/20210222zhujunyi.jpg
# 已合成并保存：./cropped_img/20210224chendawei.jpg
# 已合成并保存：./cropped_img/20210301daijiayi.jpg
# 已合成并保存：./cropped_img/20210304tangtian.jpg
# 已合成并保存：./cropped_img/20210315zourunling.jpg
# 已合成并保存：./cropped_img/20210318heyuan.jpg
# 已合成并保存：./cropped_img/20210322xuxiaohan.jpg
# 已合成并保存：./cropped_img/20210325gaoyixin.jpg
# 已合成并保存：./cropped_img/20210325tangyichen.jpg
# 已合成并保存：./cropped_img/20210408shichenkai.jpg
# 已合成并保存：./cropped_img/20210412lizixuan.jpg
